# %%
import json
import numpy as np
import getpass
import random
import pandas as pd 
seed = 42

# import test dataset 
# compute metrics
# save as a csv file

# %%
name = 'test_dataset_rerank'
filename = f'{name}.json'

# file_name = 'test_dataset.json'
with open(filename, 'r') as file:
    test_dataset = json.load(file)

print("JSON file imported successfully.")
# Out:
# JSON file imported successfully.

# %%
def rag_recall(links, relevant_links):

    """
    Calculate the recall metric for a Retrieval-Augmented Generation (RAG) system.

    This function computes the recall by comparing the retrieved links to the relevant links.
    Recall is defined as the ratio of correctly retrieved relevant links to the total number
    of relevant links.

    Parameters:
    links (list): A list of retrieved links from the RAG system.
    relevant_links (list): A list of links that are considered relevant for the given query.

    Returns:
    float: The recall score, ranging from 0.0 to 1.0.
        - 1.0 if all relevant links are retrieved or if there are no relevant links.
        - 0.0 if no relevant links are retrieved.
        - Otherwise, the fraction of relevant links that were retrieved.

    Examples:
    >>> rag_recall(['1', '2', '3'], ['1', '2'])
    1.0
    >>> rag_recall(['1', '2', '3'], [])
    1.0
    >>> rag_recall(['1', '2', '3'], ['5'])
    0.0
    >>> rag_recall(['1', '2', '3'], ['1', '2', '3', '4'])
    0.75

    Note:
    - The function treats links as sets, so order and duplicates are ignored.
    - If more links are retrieved than are relevant, the maximum recall is still 1.0.
    """
    
    retrieved_links = set(links)
    relevant_set = set(relevant_links)
    
    num_correctly_retrieved = len(retrieved_links.intersection(relevant_set))
    num_relevant = len(relevant_set)

    if num_correctly_retrieved >= num_relevant:
        return 1.0
    elif num_relevant == 0:
        return 1.0
    elif num_correctly_retrieved == 0:
        return 0.0
    else:
        return num_correctly_retrieved/num_relevant

# %%
def get_recall_scores(test_dataset):
    
    recall_scores = [] 

    for i in range(len(test_dataset)):
        relevant_links = test_dataset[i]['links']
        links = test_dataset[i]['rag_links'] 
        score = rag_recall(links, relevant_links) 
        recall_scores.append({'question': test_dataset[i]['question'], 'recall': score })
    
    return recall_scores

recall_scores = get_recall_scores(test_dataset)

# %%
pd.DataFrame(recall_scores)
# Out:
#                                              question  recall
# 0   Was sind die rechtlichen Grundlagen meines Stu...     0.0
# 1                        Was ist eine Datenabschrift?     0.0
# 2   Wie reiche ich einen Antrag im Studiendekanat ...     1.0
# 3   Ich habe vergessen, eine Lehrveranstaltung zu ...     1.0
# 4   Für eine Lehrveranstaltung habe ich zwar eine ...     1.0
# 5   Wie muss ich mich für ein Examen (Prüfung zu e...     0.0
# 6   Muss ich die Wiederholungsmöglichkeit von eine...     1.0
# 7        Wie kann ich mich von einem Examen abmelden?     1.0
# 8   Wie melde ich mich zu Prüfungen von Lehrverans...     1.0
# 9   Wie kann ich mich von einer Prüfung zu Lehrver...     1.0
# 10  Ich bin mit einer Note nicht einverstanden – w...     0.0
# 11  Ich kann gemäss meinem Studienplan Studienleis...     1.0
# 12  Ich möchte mein Bachelorstudium nach diesem Se...     1.0
# 13  Wie kann ich überzählige KP vom Bachelorstudiu...     1.0
# 14  BachelorfeierJedes Jahr im Herbst findet die B...     1.0
# 15               Wann erhalte ich mein Masterzeugnis?     1.0
# 16  Welche Konsequenzen könnte es haben, wenn man ...     1.0
# 17         Wann und für wen findet die Bachelorfeier?     1.0
# 18               Wie melde ich mich zu den Examen an?     0.0
# 19  Muss ich die Hauptvorlesung erneut belegen, um...     1.0
# 20  Ich möchte das Examen noch nicht machen, kann ...     1.0
# 21  Ich kann die ungenügende Note zur Hauptvorlesu...     1.0
# 22  Wie melde ich mich von Examen (Prüfungen zu Ha...     1.0
# 23     Wie kann ich eine Prüfungseinsicht beantragen?     1.0
# 24  Wann bekomme ich meine Abschlussunterlagen (Ba...     1.0
# 25             Wer wird zur Bachelorfeier eingeladen?     1.0
# 26  Wann bekomme ich meine Abschlussunterlagen (Ma...     1.0
# 27  Wann sehe ich die Kreditpunkte in meiner Leist...     1.0
# 28           Wie beanstande ich ein Prüfungsergebnis?     1.0
# 29  Kann ich KP, die ich an einer anderen Universi...     1.0
# 30  Was sind die Termine für die Einreichung der D...     0.0
# 31  Schickt das Dekanat die Formulare für die Guta...     1.0
# 32  Können die Gutachten nach Ablauf der Frist ein...     1.0
# 33  Kann ich mich nach dem Doktoratsexamen exmatri...     1.0

# %% [markdown]
# ## Cosine Similarity

# %%
openai_api_key = getpass.getpass("Enter your OpenAI API Key:\n\n")
# Out:
# Enter your OpenAI API Key:
#
#  ········

# %%
# Checks connection to OpenAI 
import openai
from openai import OpenAI
client = OpenAI(api_key = openai_api_key)
try:
  #Make your OpenAI API request here
  response = client.chat.completions.create(
    messages=[{"role": "user", "content": "Hello world"}],
    model="gpt-4o-mini"
  )
except openai.APIError as e:
  #Handle API error here, e.g. retry or log
  print(f"OpenAI API returned an API Error: {e}")
  pass
except openai.APIConnectionError as e:
  #Handle connection error here
  print(f"Failed to connect to OpenAI API: {e}")
  pass
except openai.RateLimitError as e:
  #Handle rate limit error (we recommend using exponential backoff)
  print(f"OpenAI API request exceeded rate limit: {e}")
  pass

# %%
def get_embedding(text):
    """Generate an embedding for the given text using OpenAI's API."""

    # Check for valid input
    if not text or not isinstance(text, str):
        return None

    try:
        # Call OpenAI API to get the embedding
        openai.api_key = openai_api_key
        
        embedding = openai.embeddings.create(
            input=text,
            model="text-embedding-ada-002").data[0].embedding
        return embedding
    except Exception as e:
        print(f"Error in get_embedding: {e}")
        return None

# %%
def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

def compare_strings(str1: str, str2: str):
    # Get embeddings for both strings
    embedding1 = get_embedding(str1)
    embedding2 = get_embedding(str2)
    
    # Calculate cosine similarity
    similarity = cosine_similarity(embedding1, embedding2)
    
    return similarity



rec  = 0 
query = test_dataset[rec]['question']
human_answer =  test_dataset[rec]['answer']
rag_answer = test_dataset[rec]['rag_answer']
similarity_score = compare_strings(human_answer, rag_answer)

print('------------------------------------------------------------------------------')
print("Q: ", query)
print('------------------------------------------------------------------------------')
print("Human answer: ", human_answer)
print('------------------------------------------------------------------------------')
print("RAG answer:", rag_answer)

print('------------------------------------------------------------------------------') 
print(f"Semantic similarity between Human and RAG answers: {similarity_score:.4f}\n")
# Out:
# ------------------------------------------------------------------------------
# Q:  Was sind die rechtlichen Grundlagen meines Studiums?
# ------------------------------------------------------------------------------
# Human answer:  Alle generellen Fragen rund um das Studium an der Universität Basel werden in den folgenden Ordnungen geregelt: Studierendenordnung (gilt für alle Studierenden der Uni Basel):   Bachelorstudium: Ordnung der Philosophisch Naturwissenschaftlichen Fakultät der Universität Basel für das Bachelorstudium-     Masterstudium: Ordnung der Philosophisch-Naturwissenschaftlichen Fakultät der Universität Basel für das MasterstudiumDiese Ordnungen gelten für alle Studierenden,  die entweder an der Phil.-Nat. Fakultät immatrikuliert sind, oder eine Lehrveranstaltung besuchen, die von der Phil.-Nat. Fakultät angeboten wird):
# ------------------------------------------------------------------------------
# RAG answer: Die rechtlichen Grundlagen deines Studiums an der Universität Basel sind in verschiedenen Ordnungen und Regelungen festgelegt. Dazu gehören unter anderem:
#
# 1. **Zulassung**: Die Zulassung zu den Studiengängen erfolgt gemäß den Zulassungsrichtlinien des Rektorats und den spezifischen Ordnungen der Fakultäten. Es gibt bestimmte Kriterien, die erfüllt sein müssen, um zum Bachelor- oder Masterstudium zugelassen zu werden, wie beispielsweise das Vorliegen eines anerkannten Reifezeugnisses oder eines Bachelorabschlusses.
#
# 2. **Studienordnungen**: Jede Fakultät hat ihre eigenen Studien- und Promotionsordnungen, die spezifische Regelungen zu den Disziplinarmaßnahmen, den Studienleistungen und den Prüfungsmodalitäten enthalten.
#
# 3. **Kreditpunkte**: Der Erwerb von Kreditpunkten erfolgt nach dem European Credit Transfer and Accumulation System (ECTS), wobei ein Kreditpunkt einem Arbeitsaufwand von etwa 30 Stunden entspricht. Die Anzahl der Kreditpunkte, die für verschiedene Lehrveranstaltungen vergeben werden, ist in den jeweiligen Studienplänen geregelt.
#
# 4. **Leistungsüberprüfungen**: Die Überprüfung der studentischen Leistungen erfolgt durch verschiedene Arten von Prüfungen, die in den Studienordnungen festgelegt sind. Die Noten werden auf einer Skala von 1.0 bis 6.0 vergeben, wobei mindestens die Note 4.0 zum Bestehen erforderlich ist.
#
# 5. **Rechte der Studierenden**: Studierende haben bestimmte Rechte, wie den Zugang zu speziellen Einrichtungen und die Möglichkeit, Anträge auf Vergünstigungen und Stipendien zu stellen.
#
# Für detaillierte Informationen zu spezifischen Regelungen und Verfahren ist es ratsam, die offiziellen Dokumente der Universität Basel zu konsultieren oder sich direkt an die Studienberatung zu wenden.
# ------------------------------------------------------------------------------
# Semantic similarity between Human and RAG answers: 0.9170

# %%
similarity_scores = []

for rec in range(len(test_dataset)):
    query = test_dataset[rec]['question']
    human_answer =  test_dataset[rec]['answer']
    rag_answer = test_dataset[rec]['rag_answer']
    similarity_score = compare_strings(human_answer, rag_answer)
    similarity_scores.append({'question': query, 'cosine_similarity': similarity_score })

# %%
pd.DataFrame(similarity_scores)
# Out:
#                                              question  cosine_similarity
# 0   Was sind die rechtlichen Grundlagen meines Stu...           0.917026
# 1                        Was ist eine Datenabschrift?           0.943508
# 2   Wie reiche ich einen Antrag im Studiendekanat ...           0.889022
# 3   Ich habe vergessen, eine Lehrveranstaltung zu ...           0.897189
# 4   Für eine Lehrveranstaltung habe ich zwar eine ...           0.862164
# 5   Wie muss ich mich für ein Examen (Prüfung zu e...           0.847319
# 6   Muss ich die Wiederholungsmöglichkeit von eine...           0.969094
# 7        Wie kann ich mich von einem Examen abmelden?           0.957648
# 8   Wie melde ich mich zu Prüfungen von Lehrverans...           0.936907
# 9   Wie kann ich mich von einer Prüfung zu Lehrver...           0.878331
# 10  Ich bin mit einer Note nicht einverstanden – w...           0.910860
# 11  Ich kann gemäss meinem Studienplan Studienleis...           0.854081
# 12  Ich möchte mein Bachelorstudium nach diesem Se...           0.880952
# 13  Wie kann ich überzählige KP vom Bachelorstudiu...           0.815740
# 14  BachelorfeierJedes Jahr im Herbst findet die B...           0.908452
# 15               Wann erhalte ich mein Masterzeugnis?           0.955098
# 16  Welche Konsequenzen könnte es haben, wenn man ...           0.886168
# 17         Wann und für wen findet die Bachelorfeier?           0.915453
# 18               Wie melde ich mich zu den Examen an?           0.941560
# 19  Muss ich die Hauptvorlesung erneut belegen, um...           0.920898
# 20  Ich möchte das Examen noch nicht machen, kann ...           0.910479
# 21  Ich kann die ungenügende Note zur Hauptvorlesu...           0.909053
# 22  Wie melde ich mich von Examen (Prüfungen zu Ha...           0.903696
# 23     Wie kann ich eine Prüfungseinsicht beantragen?           0.946113
# 24  Wann bekomme ich meine Abschlussunterlagen (Ba...           0.931598
# 25             Wer wird zur Bachelorfeier eingeladen?           0.882008
# 26  Wann bekomme ich meine Abschlussunterlagen (Ma...           0.925974
# 27  Wann sehe ich die Kreditpunkte in meiner Leist...           0.809620
# 28           Wie beanstande ich ein Prüfungsergebnis?           0.904352
# 29  Kann ich KP, die ich an einer anderen Universi...           0.894594
# 30  Was sind die Termine für die Einreichung der D...           0.749909
# 31  Schickt das Dekanat die Formulare für die Guta...           0.883385
# 32  Können die Gutachten nach Ablauf der Frist ein...           0.910157
# 33  Kann ich mich nach dem Doktoratsexamen exmatri...           0.928168

# %% [markdown]
# ## Jaccard Similarity

# %%
def jaccard_similarity(set1, set2):
    # Convert inputs to sets if they're not already
    set1 = set(set1)
    set2 = set(set2)
    
    # Calculate intersection and union
    intersection = set1.intersection(set2)
    union = set1.union(set2)
    
    # Compute Jaccard Similarity
    similarity = len(intersection) / len(union)
    
    return similarity

def jaccard_similarity_text(text1, text2):
    # Convert texts to sets of words
    set1 = set(text1.lower().split())
    set2 = set(text2.lower().split())
    
    return jaccard_similarity(set1, set2)

# Example usage
text1 = "I like dogs"
text2 = "I hate dogs"

similarity = jaccard_similarity_text(text1, text2)
print(f"Jaccard Similarity: {similarity}")
# Out:
# Jaccard Similarity: 0.5

# %%
jaccard_scores = []

for rec in range(len(test_dataset)):
    query = test_dataset[rec]['question']
    human_answer =  test_dataset[rec]['answer']
    rag_answer = test_dataset[rec]['rag_answer']
    jaccard_similarity_score = jaccard_similarity_text(human_answer, rag_answer) 
    jaccard_scores.append({'question': query, 'jaccard_similarity': jaccard_similarity_score })

# %%
pd.DataFrame(jaccard_scores)
# Out:
#                                              question  jaccard_similarity
# 0   Was sind die rechtlichen Grundlagen meines Stu...            0.081522
# 1                        Was ist eine Datenabschrift?            0.156250
# 2   Wie reiche ich einen Antrag im Studiendekanat ...            0.088757
# 3   Ich habe vergessen, eine Lehrveranstaltung zu ...            0.082090
# 4   Für eine Lehrveranstaltung habe ich zwar eine ...            0.084034
# 5   Wie muss ich mich für ein Examen (Prüfung zu e...            0.087248
# 6   Muss ich die Wiederholungsmöglichkeit von eine...            0.325843
# 7        Wie kann ich mich von einem Examen abmelden?            0.276243
# 8   Wie melde ich mich zu Prüfungen von Lehrverans...            0.088496
# 9   Wie kann ich mich von einer Prüfung zu Lehrver...            0.050000
# 10  Ich bin mit einer Note nicht einverstanden – w...            0.192771
# 11  Ich kann gemäss meinem Studienplan Studienleis...            0.026316
# 12  Ich möchte mein Bachelorstudium nach diesem Se...            0.086207
# 13  Wie kann ich überzählige KP vom Bachelorstudiu...            0.068627
# 14  BachelorfeierJedes Jahr im Herbst findet die B...            0.114583
# 15               Wann erhalte ich mein Masterzeugnis?            0.104651
# 16  Welche Konsequenzen könnte es haben, wenn man ...            0.131783
# 17         Wann und für wen findet die Bachelorfeier?            0.162791
# 18               Wie melde ich mich zu den Examen an?            0.108974
# 19  Muss ich die Hauptvorlesung erneut belegen, um...            0.175000
# 20  Ich möchte das Examen noch nicht machen, kann ...            0.122951
# 21  Ich kann die ungenügende Note zur Hauptvorlesu...            0.105263
# 22  Wie melde ich mich von Examen (Prüfungen zu Ha...            0.115044
# 23     Wie kann ich eine Prüfungseinsicht beantragen?            0.140187
# 24  Wann bekomme ich meine Abschlussunterlagen (Ba...            0.160920
# 25             Wer wird zur Bachelorfeier eingeladen?            0.096154
# 26  Wann bekomme ich meine Abschlussunterlagen (Ma...            0.085714
# 27  Wann sehe ich die Kreditpunkte in meiner Leist...            0.051948
# 28           Wie beanstande ich ein Prüfungsergebnis?            0.131148
# 29  Kann ich KP, die ich an einer anderen Universi...            0.237288
# 30  Was sind die Termine für die Einreichung der D...            0.015873
# 31  Schickt das Dekanat die Formulare für die Guta...            0.078431
# 32  Können die Gutachten nach Ablauf der Frist ein...            0.081633
# 33  Kann ich mich nach dem Doktoratsexamen exmatri...            0.072727

# %% [markdown]
# ## Unit Tests

# %%
def generate_answer(prompt):
    response = client.chat.completions.create(
        model='gpt-4o-mini',
        messages=[{"role": "user", "content": prompt}],
        temperature=0
    )

    response_content = response.choices[0].message.content
    return response_content
    
def unit_test_text(question, expected_answer, rag_answer):
    
    prompt_evaluation = """
    Question: {question}
    Expected Response: {expected_response}
    Actual Response: {actual_response}
    
    (Answer with 'True' or 'False') Does the Actual Response provide the necessary information for the question as the Expected Response does?
    """.strip()

    response = generate_answer(prompt_evaluation.format(question = question, expected_response = expected_answer, actual_response = rag_answer))

    return response

# %%
# rec = 0 
# query = test_dataset[rec]['question']
# human_answer =  test_dataset[rec]['answer']
# rag_answer = test_dataset[rec]['rag_answer']

# unit_test_text(query, human_answer, rag_answer)

# %%
rag_answer
# Out:
# 'Ja, Sie können sich nach dem bestandenen Doktoratsexamen exmatrikulieren. Die Exmatrikulation kann erfolgen, nachdem Sie das Examen erfolgreich abgelegt haben. Es ist wichtig, dass Sie alle erforderlichen Schritte und Fristen beachten, um sicherzustellen, dass Ihre Exmatrikulation reibungslos verläuft. Wenn Sie weitere Fragen haben oder spezifische Informationen benötigen, empfehle ich, sich direkt an das Studiendekanat der Universität Basel zu wenden.'

# %%
unit_tests = []

for rec in range(len(test_dataset)):
    query = test_dataset[rec]['question']
    human_answer =  test_dataset[rec]['answer']
    rag_answer = test_dataset[rec]['rag_answer']
    unit_tests.append({'question': query, 'unit_test': unit_test_text(query, human_answer, rag_answer) })

# %%
pd.DataFrame(unit_tests)
# Out:
#                                              question unit_test
# 0   Was sind die rechtlichen Grundlagen meines Stu...      True
# 1                        Was ist eine Datenabschrift?      True
# 2   Wie reiche ich einen Antrag im Studiendekanat ...     False
# 3   Ich habe vergessen, eine Lehrveranstaltung zu ...     False
# 4   Für eine Lehrveranstaltung habe ich zwar eine ...     False
# 5   Wie muss ich mich für ein Examen (Prüfung zu e...      True
# 6   Muss ich die Wiederholungsmöglichkeit von eine...      True
# 7        Wie kann ich mich von einem Examen abmelden?      True
# 8   Wie melde ich mich zu Prüfungen von Lehrverans...      True
# 9   Wie kann ich mich von einer Prüfung zu Lehrver...     False
# 10  Ich bin mit einer Note nicht einverstanden – w...      True
# 11  Ich kann gemäss meinem Studienplan Studienleis...     False
# 12  Ich möchte mein Bachelorstudium nach diesem Se...      True
# 13  Wie kann ich überzählige KP vom Bachelorstudiu...     False
# 14  BachelorfeierJedes Jahr im Herbst findet die B...     False
# 15               Wann erhalte ich mein Masterzeugnis?      True
# 16  Welche Konsequenzen könnte es haben, wenn man ...     False
# 17         Wann und für wen findet die Bachelorfeier?      True
# 18               Wie melde ich mich zu den Examen an?      True
# 19  Muss ich die Hauptvorlesung erneut belegen, um...      True
# 20  Ich möchte das Examen noch nicht machen, kann ...     False
# 21  Ich kann die ungenügende Note zur Hauptvorlesu...     False
# 22  Wie melde ich mich von Examen (Prüfungen zu Ha...      True
# 23     Wie kann ich eine Prüfungseinsicht beantragen?      True
# 24  Wann bekomme ich meine Abschlussunterlagen (Ba...     False
# 25             Wer wird zur Bachelorfeier eingeladen?     False
# 26  Wann bekomme ich meine Abschlussunterlagen (Ma...      True
# 27  Wann sehe ich die Kreditpunkte in meiner Leist...     False
# 28           Wie beanstande ich ein Prüfungsergebnis?      True
# 29  Kann ich KP, die ich an einer anderen Universi...      True
# 30  Was sind die Termine für die Einreichung der D...     False
# 31  Schickt das Dekanat die Formulare für die Guta...      True
# 32  Können die Gutachten nach Ablauf der Frist ein...      True
# 33  Kann ich mich nach dem Doktoratsexamen exmatri...      True

# %% [markdown]
# ## Save results in CSV

# %%
# unit_tests
# jaccard_scores
# similarity_scores
# recall_scores

unit_test_df =  pd.DataFrame.from_dict(unit_tests)
jaccard_df =  pd.DataFrame.from_dict(jaccard_scores)
cosine_sim_df = pd.DataFrame.from_dict(similarity_scores)
recall_df = pd.DataFrame.from_dict(recall_scores)
df = pd.DataFrame.from_dict(test_dataset)


# merged_df = pd.DataFrame.from_dict(test_dataset).merge(
#     pd.DataFrame.from_dict(unit_tests), on='question', how='left'
# ).merge(
#     pd.DataFrame.from_dict(jaccard_scores), on='question', how='left'
# ).merge(
#     pd.DataFrame.from_dict(similarity_scores), on='question', how='left'
# ).merge(
#     pd.DataFrame.from_dict(recall_scores), on='question', how='left'
# )

#merged_df.to_csv(f'scored_{file_name}.csv', index=False, float_format='%.4f')

# %%
merged_df = pd.concat([df, unit_test_df['unit_test'],jaccard_df['jaccard_similarity'], cosine_sim_df['cosine_similarity'], recall_df['recall']], axis=1)
merged_df.to_csv(f'scored_{name}.csv', index=False, float_format='%.4f')

# %% [markdown]
# ---
# * Author: Anastasiia Popova
# * Email: anastasiia.popova@stud.unibas.ch
#
# [Perplexity AI](https://www.perplexity.ai/) assisted in code writing, editing, and more effective information searches. The generated output underwent critical evaluation. The author is solely responsible for the content.
